# %% [markdown]
# <a href="https://colab.research.google.com/github/martiK1ll3r/Shaman-tools/blob/main/Shaman_tools.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Simulación de base de datos para usuarios y productos

# Usuarios iniciales
usuarios = {
    "Ren Tao": {"password": "1234_4321", "rol": "admin"},
    "Ioh Asakura": {"password": "abc_cba", "rol": "vendedor"},
    "Chocolove McDonnell": {"password": "11110000", "rol": "vendedor"}
}

# Productos iniciales
productos = {
    "1": {"nombre": "Ladrillo 10x20x30", "precio_compra": 1200.00, "precio_venta": 1500.00, "cantidad": 1000, "unidad": "un"},
    "2": {"nombre": "Cemento Gris x50kg", "precio_compra": 28000.00, "precio_venta": 30000.00, "cantidad": 200, "unidad": "saco"},
    "3": {"nombre": "Varilla Corrugada #5 x6m", "precio_compra": 33000.00, "precio_venta": 35000.00, "cantidad": 150, "unidad": "un"},
    "4": {"nombre": "Impermeabilizante 22kg", "precio_compra": 350000.00, "precio_venta": 360000.00, "cantidad": 50, "unidad": "un"},
    "5": {"nombre": "Malla Electro Soldada 6x2.2m", "precio_compra": 42000.00, "precio_venta": 45000.00, "cantidad": 75, "unidad": "un"}
}

# Lista para almacenar las ventas
ventas = []

def main():
    print("Pantalla inicial del sistema de inventario")
    while True:
        print("\nMenú Principal")
        print("1: Login")
        print("2: Salir")
        opcion = int(input("Seleccione una opción: "))

        if opcion == 2:
            print("Cerrando el sistema...")
            break
        elif opcion == 1:
            login()

def login():
    while True:
        nombre = input("Ingrese nombre de usuario: ")
        contraseña = input("Ingrese contraseña: ")

        if nombre in usuarios and usuarios[nombre]["password"] == contraseña:
            rol = usuarios[nombre]["rol"]
            print(f"\nBienvenido, {nombre}. Menú según el rol.")
            if rol == "admin":
                admin_menu()
            else:
                vendedor_menu()
            break
        else:
            print("Error: Credenciales incorrectas")

def admin_menu():
    while True:
        print("\nMenú Admin")
        print("1: Registrar usuario")
        print("2: Agregar/actualizar producto")
        print("3: Consultar inventario")
        print("4: Comprar productos")
        print("5: Ver resumen de ventas")
        print("6: Salir")
        opcion = int(input("Seleccione una opción: "))

        if opcion == 1:
            registrar_usuario()
        elif opcion == 2:
            agregar_actualizar_producto()
        elif opcion == 3:
            consultar_inventario()
        elif opcion == 4:
            comprar_productos()
        elif opcion == 5:
            ver_resumen_ventas()
        elif opcion == 6:
            break

def vendedor_menu():
    while True:
        print("\nMenú Vendedor")
        print("1: Consultar productos")
        print("2: Vender productos")
        print("3: Salir")
        opcion = int(input("Seleccione una opción: "))

        if opcion == 1:
            consultar_inventario()
        elif opcion == 2:
            vender_productos()
        elif opcion == 3:
            break

def registrar_usuario():
    nuevo_nombre = input("Ingrese nombre del nuevo usuario: ")
    nueva_contraseña = input("Ingrese contraseña del nuevo usuario: ")
    nuevo_rol = input("Ingrese rol del nuevo usuario (admin/vendedor): ")
    if nuevo_nombre in usuarios:
        print("Error: El usuario ya existe.")
    else:
        usuarios[nuevo_nombre] = {"password": nueva_contraseña, "rol": nuevo_rol}
        print(f"Usuario {nuevo_nombre} registrado con éxito.")

def agregar_actualizar_producto():
    codigo = input("Ingrese código del producto: ")
    nombre = input("Ingrese nombre del producto: ")
    precio_compra = float(input("Ingrese precio de compra del producto: "))
    precio_venta = float(input("Ingrese precio de venta del producto: "))
    cantidad = int(input("Ingrese cantidad del producto: "))
    unidad = input("Ingrese unidad del producto: ")

    if codigo in productos:
        productos[codigo]["cantidad"] += cantidad
        print(f"Cantidad de {nombre} actualizada.")
    else:
        productos[codigo] = {"nombre": nombre, "precio_compra": precio_compra, "precio_venta": precio_venta, "cantidad": cantidad, "unidad": unidad}
        print(f"Producto {nombre} agregado con éxito.")

def consultar_inventario():
    codigo = input("Ingrese código del producto o presione '0' para listar todos: ")

    if codigo == "0":
        print("\nInventario completo:")
        for codigo, detalles in productos.items():
            print(f"{codigo}: {detalles['nombre']}, Precio de Compra: {detalles['precio_compra']}, Precio de Venta: {detalles['precio_venta']}, Cantidad: {detalles['cantidad']}, Unidad: {detalles['unidad']}")
    elif codigo in productos:
        detalles = productos[codigo]
        print(f"{codigo}: {detalles['nombre']}, Precio de Compra: {detalles['precio_compra']}, Precio de Venta: {detalles['precio_venta']}, Cantidad: {detalles['cantidad']}, Unidad: {detalles['unidad']}")
    else:
        print("Error: Producto no encontrado.")

def comprar_productos():
    codigo = input("Ingrese código del producto: ")
    cantidad = int(input("Ingrese cantidad a comprar: "))

    if codigo in productos:
        productos[codigo]["cantidad"] += cantidad
        print(f"Compra de {cantidad} unidades de {productos[codigo]['nombre']} realizada con éxito.")
    else:
        nombre = input("Ingrese nombre del nuevo producto: ")
        precio_compra = float(input("Ingrese precio de compra del nuevo producto: "))
        precio_venta = float(input("Ingrese precio de venta del nuevo producto: "))
        unidad = input("Ingrese unidad del nuevo producto: ")
        productos[codigo] = {"nombre": nombre, "precio_compra": precio_compra, "precio_venta": precio_venta, "cantidad": cantidad, "unidad": unidad}
        print(f"Nuevo producto {nombre} agregado al inventario.")

def ver_resumen_ventas():
    print("\nResumen de ventas:")
    for venta in ventas:
        print(f"Código: {venta['codigo']}, Cantidad vendida: {venta['cantidad']}, Total generado: {venta['total']}")

def vender_productos():
    codigo = input("Ingrese código del producto: ")
    cantidad = int(input("Ingrese cantidad a vender: "))

    if codigo in productos and productos[codigo]["cantidad"] >= cantidad:
        total = cantidad * productos[codigo]["precio_venta"]
        productos[codigo]["cantidad"] -= cantidad
        ventas.append({"codigo": codigo, "cantidad": cantidad, "total": total})
        print(f"Venta de {cantidad} unidades de {productos[codigo]['nombre']} realizada con éxito. Total: {total}")
    else:
        print("Error: No hay suficiente inventario para esta venta.")

# Inicia el sistema de inventario
main()
# Out:
# Pantalla inicial del sistema de inventario
#
# Menú Principal
# 1: Login
# 2: Salir
# Seleccione una opción: 1
# Ingrese nombre de usuario: Ioh Asakura
# Ingrese contraseña: abc_cba
#
# Bienvenido, Ioh Asakura. Menú según el rol.
#
# Menú Vendedor
# 1: Consultar productos
# 2: Vender productos
# 3: Salir
# Seleccione una opción: 1
# Ingrese código del producto o presione '0' para listar todos: 0
#
# Inventario completo:
# 1: Ladrillo 10x20x30, Precio de Compra: 1200.0, Precio de Venta: 1500.0, Cantidad: 1000, Unidad: un
# 2: Cemento Gris x50kg, Precio de Compra: 28000.0, Precio de Venta: 30000.0, Cantidad: 200, Unidad: saco
# 3: Varilla Corrugada #5 x6m, Precio de Compra: 33000.0, Precio de Venta: 35000.0, Cantidad: 150, Unidad: un
# 4: Impermeabilizante 22kg, Precio de Compra: 350000.0, Precio de Venta: 360000.0, Cantidad: 50, Unidad: un
# 5: Malla Electro Soldada 6x2.2m, Precio de Compra: 42000.0, Precio de Venta: 45000.0, Cantidad: 75, Unidad: un
#
# Menú Vendedor
# 1: Consultar productos
# 2: Vender productos
# 3: Salir
# Seleccione una opción: 2
# Ingrese código del producto: 1
# Ingrese cantidad a vender: 20
# Venta de 20 unidades de Ladrillo 10x20x30 realizada con éxito. Total: 30000.0
#
# Menú Vendedor
# 1: Consultar productos
# 2: Vender productos
# 3: Salir
# Seleccione una opción: 3
#
# Menú Principal
# 1: Login
# 2: Salir
# Seleccione una opción: 1
# Ingrese nombre de usuario: Ren Tao
# Ingrese contraseña: 1234_4321
#
# Bienvenido, Ren Tao. Menú según el rol.
#
# Menú Admin
# 1: Registrar usuario
# 2: Agregar/actualizar producto
# 3: Consultar inventario
# 4: Comprar productos
# 5: Ver resumen de ventas
# 6: Salir
# Seleccione una opción: 3
# Ingrese código del producto o presione '0' para listar todos: 0
#
# Inventario completo:
# 1: Ladrillo 10x20x30, Precio de Compra: 1200.0, Precio de Venta: 1500.0, Cantidad: 980, Unidad: un
# 2: Cemento Gris x50kg, Precio de Compra: 28000.0, Precio de Venta: 30000.0, Cantidad: 200, Unidad: saco
# 3: Varilla Corrugada #5 x6m, Precio de Compra: 33000.0, Precio de Venta: 35000.0, Cantidad: 150, Unidad: un
# 4: Impermeabilizante 22kg, Precio de Compra: 350000.0, Precio de Venta: 360000.0, Cantidad: 50, Unidad: un
# 5: Malla Electro Soldada 6x2.2m, Precio de Compra: 42000.0, Precio de Venta: 45000.0, Cantidad: 75, Unidad: un
#
# Menú Admin
# 1: Registrar usuario
# 2: Agregar/actualizar producto
# 3: Consultar inventario
# 4: Comprar productos
# 5: Ver resumen de ventas
# 6: Salir
# Seleccione una opción: 5
#
# Resumen de ventas:
# Código: 1, Cantidad vendida: 20, Total generado: 30000.0
#
# Menú Admin
# 1: Registrar usuario
# 2: Agregar/actualizar producto
# 3: Consultar inventario
# 4: Comprar productos
# 5: Ver resumen de ventas
# 6: Salir
# Seleccione una opción: 4
# Ingrese código del producto: 6
# Ingrese cantidad a comprar: 50
# Ingrese nombre del nuevo producto: clavos
# Ingrese precio de compra del nuevo producto: 2000
# Ingrese precio de venta del nuevo producto: 2500
# Ingrese unidad del nuevo producto: caja
# Nuevo producto clavos agregado al inventario.
#
# Menú Admin
# 1: Registrar usuario
# 2: Agregar/actualizar producto
# 3: Consultar inventario
# 4: Comprar productos
# 5: Ver resumen de ventas
# 6: Salir
# Seleccione una opción: 3
# Ingrese código del producto o presione '0' para listar todos: 0
#
# Inventario completo:
# 1: Ladrillo 10x20x30, Precio de Compra: 1200.0, Precio de Venta: 1500.0, Cantidad: 980, Unidad: un
# 2: Cemento Gris x50kg, Precio de Compra: 28000.0, Precio de Venta: 30000.0, Cantidad: 200, Unidad: saco
# 3: Varilla Corrugada #5 x6m, Precio de Compra: 33000.0, Precio de Venta: 35000.0, Cantidad: 150, Unidad: un
# 4: Impermeabilizante 22kg, Precio de Compra: 350000.0, Precio de Venta: 360000.0, Cantidad: 50, Unidad: un
# 5: Malla Electro Soldada 6x2.2m, Precio de Compra: 42000.0, Precio de Venta: 45000.0, Cantidad: 75, Unidad: un
# 6: clavos, Precio de Compra: 2000.0, Precio de Venta: 2500.0, Cantidad: 50, Unidad: caja
#
# Menú Admin
# 1: Registrar usuario
# 2: Agregar/actualizar producto
# 3: Consultar inventario
# 4: Comprar productos
# 5: Ver resumen de ventas
# 6: Salir
# Seleccione una opción: 6
#
# Menú Principal
# 1: Login
# 2: Salir
# Seleccione una opción: 2
# Cerrando el sistema...
